# %% [markdown]
# # My First Machine Learning Project

# %% [markdown]
# In October, A Cloud Guru reopened one of their challenges - [Machine Learning on AWS](https://acloudguru.com/blog/engineering/the-cloud-guru-challenge-aws-machine-learning). I was excited to join as I had been wanting to explore Machine Learning on AWS for some time. I spent hours reading documentation and watching videos to understand things such as Jupyter Notebook, Amazon Sagemaker, and K-Means clustering. I not only learned a lot but also had fun which is very important to me. 😊

# %% [markdown]
# ## My solution:

# %% [markdown]
# Download and load the datasets.<br><br>*I thought of using the [datasets from GroupLens](https://grouplens.org/datasets/movielens/) as they have user data but I decided to use the [datasets from IMDB](https://datasets.imdbws.com/) to find out if movies could be grouped without user data.*

# %%
import os
import pandas
import urllib.request

dataset_urls = ['https://datasets.imdbws.com/title.basics.tsv.gz',
                'https://datasets.imdbws.com/title.ratings.tsv.gz']

for dataset_url in dataset_urls:
    dataset_file = os.path.basename(dataset_url)
    if not os.path.exists(dataset_file):
        urllib.request.urlretrieve(dataset_url, dataset_file)
        
try:
    basics
except NameError:
    basics = pandas.read_csv('title.basics.tsv.gz', sep='\t', low_memory=False)
    
try:
    ratings
except NameError:
    ratings = pandas.read_csv('title.ratings.tsv.gz', sep='\t', low_memory=False)

# %% [markdown]
# Check if all of the title ids in the basics dataset are unique.

# %%
basics['tconst'].is_unique
# Out:
# True

# %% [markdown]
# Check if all of the title ids in the ratings dataset are unique.

# %%
ratings['tconst'].is_unique
# Out:
# True

# %% [markdown]
# Merge the basics and ratings datasets.

# %%
titles = basics.merge(ratings, left_on='tconst', right_on='tconst')

# %% [markdown]
# Exclude the titles that are not movies and that have less than 25,000 votes.<br><br>*I copied this number from IMDB's [Ratings FAQ](https://help.imdb.com/article/imdb/track-movies-tv/ratings-faq/G67Y87TFYYP6TWAV#) page.*

# %%
minVotes = 25000

titles = titles[(titles['titleType'] == 'movie') & (titles['numVotes'] >= minVotes)]

# %% [markdown]
# Calculate the weighted ratings according to the formula from IMDB's [Ratings FAQ](https://help.imdb.com/article/imdb/track-movies-tv/ratings-faq/G67Y87TFYYP6TWAV#) page.<br><br>*I wanted to find out if using weighted ratings would produce better results than using average ratings.*

# %%
overallAverageRating = (titles['averageRating'] * titles['numVotes']).sum() / titles['numVotes'].sum()
titles['weightedRating'] = (titles['numVotes'] / (titles['numVotes'] + minVotes)) * titles['averageRating'] + (minVotes / (titles['numVotes'] + minVotes)) * overallAverageRating

titles.reset_index(drop=True, inplace=True)

# %% [markdown]
# Prepare the data.

# %%
X = titles['genres'].to_frame()

# %% [markdown]
# Split the genres and check if all of the values are expected.

# %%
all_genres = []
for genres in X['genres'].str.split(','):
    for genre in genres:
        if genre not in all_genres:
            all_genres.append(genre)
            
all_genres
# Out:
# ['Horror',
#  'Mystery',
#  'Thriller',
#  'Comedy',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'Action',
#  'Romance',
#  'History',
#  'Adventure',
#  'Sci-Fi',
#  'Biography',
#  'War',
#  'Crime',
#  'Musical',
#  'Music',
#  'Animation',
#  'Western',
#  'Film-Noir',
#  'Sport',
#  'Documentary',
#  'News']

# %% [markdown]
# Convert the genres column to one-hot columns as KMeans cannot use categorical data.

# %%
all_genres.sort()

for genre in all_genres:
    X[genre.lower()] = X['genres'].str.contains(genre)
    
X.drop('genres', axis=1, inplace=True)

# %% [markdown]
# Create the data with the average ratings.

# %%
X_averageRatings = X.join(titles['averageRating'])

# %% [markdown]
# Create the data with the weighted ratings.

# %%
X_weightedRatings = X.join(titles['weightedRating'])

# %% [markdown]
# Predict the cluster indexes.

# %%
from sklearn.cluster import KMeans

clusters_averageRatings = KMeans(n_clusters=28, random_state=0).fit_predict(X_averageRatings)

clusters_weightedRatings = KMeans(n_clusters=28, random_state=0).fit_predict(X_weightedRatings)

# %% [markdown]
# Add the cluster indexes to the titles dataset.

# %%
clusters_averageRatings = pandas.DataFrame(clusters_averageRatings, columns=['cluster_averageRating'])
titles = titles.join(clusters_averageRatings)

clusters_weightedRatings = pandas.DataFrame(clusters_weightedRatings, columns=['cluster_weightedRating'])
titles = titles.join(clusters_weightedRatings)

# %% [markdown]
# Check the predictions ...

# %%
titles[titles['primaryTitle'].str.contains('Die Hard')]
# Out:
#          tconst titleType               primaryTitle  \
# 815   tt0095016     movie                   Die Hard
# 927   tt0099423     movie                 Die Hard 2
# 1272  tt0112864     movie  Die Hard with a Vengeance
# 2354  tt0337978     movie      Live Free or Die Hard
# 4159  tt1606378     movie     A Good Day to Die Hard
#
#                    originalTitle isAdult startYear endYear runtimeMinutes  \
# 815                     Die Hard       0      1988      \N            132
# 927                   Die Hard 2       0      1990      \N            124
# 1272  Die Hard: With a Vengeance       0      1995      \N            128
# 2354       Live Free or Die Hard       0      2007      \N            128
# 4159      A Good Day to Die Hard       0      2013      \N             98
#
#                          genres  averageRating  numVotes  weightedRating  \
# 815             Action,Thriller            8.2    833119        8.171121
# 927             Action,Thriller            7.1    350802        7.107234
# 1272  Action,Adventure,Thriller            7.6    376648        7.575647
# 2354            Action,Thriller            7.1    398713        7.106416
# 4159            Action,Thriller            5.3    203558        5.508781
#
#       cluster_averageRating  cluster_weightedRating
# 815                      23                       1
# 927                      27                       1
# 1272                     23                      19
# 2354                     27                       1
# 4159                     27                       1

# %% [markdown]
# ... from the average-rating cluster ...

# %%
titles[titles['cluster_averageRating'] == 22].tail(10)
# Out:
#          tconst titleType             primaryTitle            originalTitle  \
# 4914  tt3289956     movie  The Autopsy of Jane Doe  The Autopsy of Jane Doe
# 5092  tt4178092     movie                 The Gift                 The Gift
# 5114  tt4332232     movie                Fractured                Fractured
# 5226  tt5052448     movie                  Get Out                  Get Out
# 5262  tt5354160     movie              Mirror Game                 Aynabaji
# 5350  tt6053438     movie           First Reformed           First Reformed
# 5434  tt6857112     movie                       Us                       Us
# 5456  tt7057496     movie                Forgotten            Gi-eok-ui bam
# 5500  tt7668870     movie                Searching                Searching
# 5573  tt8633478     movie                      Run                      Run
#
#      isAdult startYear endYear runtimeMinutes                   genres  \
# 4914       0      2016      \N             86  Horror,Mystery,Thriller
# 5092       0      2015      \N            108   Drama,Mystery,Thriller
# 5114       0      2019      \N             99         Mystery,Thriller
# 5226       0      2017      \N            104  Horror,Mystery,Thriller
# 5262       0      2016      \N            147   Crime,Mystery,Thriller
# 5350       0      2017      \N            113   Drama,Mystery,Thriller
# 5434       0      2019      \N            116  Horror,Mystery,Thriller
# 5456       0      2017      \N            108         Mystery,Thriller
# 5500       0      2018      \N            102   Drama,Mystery,Thriller
# 5573       0      2020      \N             90         Mystery,Thriller
#
#       averageRating  numVotes  weightedRating  cluster_averageRating  \
# 4914            6.8    109280        6.876099                     22
# 5092            7.0    149216        7.029955                     22
# 5114            6.4     66805        6.620234                     22
# 5226            7.7    541475        7.678320                     22
# 5262            9.1     25404        8.161951                     22
# 5350            7.1     53154        7.134785                     22
# 5434            6.8    263768        6.835387                     22
# 5456            7.5     27958        7.362505                     22
# 5500            7.6    154910        7.545631                     22
# 5573            6.7     62576        6.845229                     22
#
#       cluster_weightedRating
# 4914                      20
# 5092                      15
# 5114                      20
# 5226                      20
# 5262                      11
# 5350                      15
# 5434                      20
# 5456                      15
# 5500                      15
# 5573                      15

# %% [markdown]
# ... and from the weighted-rating cluster.

# %%
titles[titles['cluster_weightedRating'] == 1].tail(10)
# Out:
#          tconst titleType                           primaryTitle  \
# 5413  tt6654210     movie                               Infinite
# 5418  tt6723592     movie                                  Tenet
# 5430  tt6806448     movie  Fast & Furious Presents: Hobbs & Shaw
# 5439  tt6902332     movie                           The Marksman
# 5484  tt7456310     movie                                   Anna
# 5506  tt7737786     movie                              Greenland
# 5528  tt7991608     movie                             Red Notice
# 5531  tt8106534     movie                          6 Underground
# 5576  tt8688634     movie                             21 Bridges
# 5585  tt8936646     movie                             Extraction
#
#                               originalTitle isAdult startYear endYear  \
# 5413                               Infinite       0      2021      \N
# 5418                                  Tenet       0      2020      \N
# 5430  Fast & Furious Presents: Hobbs & Shaw       0      2019      \N
# 5439                           The Marksman       0      2021      \N
# 5484                                   Anna       0      2019      \N
# 5506                              Greenland       0      2020      \N
# 5528                             Red Notice       0      2021      \N
# 5531                          6 Underground       0      2019      \N
# 5576                             21 Bridges       0      2019      \N
# 5585                             Extraction       0      2020      \N
#
#      runtimeMinutes                     genres  averageRating  numVotes  \
# 5413            106     Action,Sci-Fi,Thriller            5.5     37946
# 5418            150     Action,Sci-Fi,Thriller            7.4    441162
# 5430            137  Action,Adventure,Thriller            6.5    198791
# 5439            108  Action,Adventure,Thriller            5.6     26844
# 5484            118            Action,Thriller            6.7     74081
# 5506            119      Action,Drama,Thriller            6.4    103977
# 5528            118     Action,Comedy,Thriller            6.4    180059
# 5531            128            Action,Thriller            6.1    159438
# 5576             99            Action,Thriller            6.6     60157
# 5585            116            Action,Thriller            6.7    184353
#
#       weightedRating  cluster_averageRating  cluster_weightedRating
# 5413        6.178654                     14                       1
# 5418        7.389743                     27                       1
# 5430        6.579175                     26                       1
# 5439        6.375761                     26                       1
# 5484        6.828365                     27                       1
# 5506        6.556761                     15                       1
# 5528        6.498599                      8                       1
# 5531        6.250287                     27                       1
# 5576        6.778712                     27                       1
# 5585        6.760752                     27                       1

# %% [markdown]
# *I checked the predictions a few more times. I like the recommendations from the weighted-rating cluster more. What do you think? 😊*

# %% [markdown]
# To dos:
# 1. Find out the optimal number of clusters.
# 2. Find out if the datasets with user data would produce better predictions.
# 3. Exclude old movies?
